# %% [markdown]
# # Stage 2 Step 6 — Medium-Run Retention/Frequency Elasticity

# %%
# !python ../scripts/week2_day6_retention_frequency.py

# %%
import pandas as pd
models = pd.read_csv('../outputs/week2_day6_retention_frequency_models.csv')
models

# %%
pd.read_csv('../outputs/week2_day6_user_week_panel_sample.csv').head()
