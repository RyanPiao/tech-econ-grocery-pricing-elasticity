# %% [markdown]
# # Stage 2 Step 2 — Production Extraction with Immutable Fee-Version Timestamps

# %%
# !python ../scripts/week2_day2_production_extraction.py

# %%
import pandas as pd
checks = pd.read_csv('../outputs/week2_day2_extraction_quality_checks.csv')
checks

# %%
pd.read_csv('../outputs/week2_day2_fee_version_catalog.csv').head(10)
