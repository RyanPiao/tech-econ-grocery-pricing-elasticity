# %% [markdown]
# # Stage 2 Step 4-5 — Heterogeneity Expansions

# %%
# !python ../scripts/week2_day4_day5_heterogeneity.py

# %%
import pandas as pd
out = pd.read_csv('../outputs/week2_day4_day5_heterogeneity_elasticity.csv')
out

# %%
pd.read_csv('../outputs/week2_day4_day5_segment_counts.csv')
