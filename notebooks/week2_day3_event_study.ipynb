# %% [markdown]
# # Week 2 Day 3 — Event-Study Lead/Lag and Pre-Trend Test

# %%
# !python ../scripts/week2_day3_event_study.py

# %%
import pandas as pd
lead_lag = pd.read_csv('../outputs/week2_day3_event_study_lead_lag_table.csv')
lead_lag

# %%
pd.read_csv('../outputs/week2_day3_pretrend_test.csv')
